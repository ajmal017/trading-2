# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
import numpy as np

# %%
projects = ['trader bot','healthcare', 'sign lang', 'var select genalga','abua']

# %%
np.random.choice(projects)
# Out:
# 'healthcare'

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# import packages we need for exploratory data analysis (EDA)
import pandas as pd # to store tabular data
import numpy as np # to do some math
import matplotlib.pyplot as plt # a popular data visualization tool
import seaborn as sns # another popular data visualization tool
# %matplotlib inline
plt.style.use('fivethirtyeight') # a popular data visualization

# %%
import pandas as pd
pd.set_option('display.max_rows', 150)
pd.set_option('display.min_rows', 150)
pd.set_option('display.max_columns', 150)

# %%
'BTC', 'LTC', 'ETH', 'ETC',  'XMR', 'DSH', 'XRP',
# Out:
# ('BTC', 'LTC', 'ETH', 'ETC', 'XMR', 'DSH', 'XRP')

# %%
all_cryptos = ['BTC', 'LTC', 'ETH', 'ETC', 'RRT', 'ZEC', 'XMR', 'DSH', 'XRP',
               'IOT', 'GTX', 'EOS', 'SAN', 'OMG', 'NEO', 'ETP', 'QTM', 'AVT',
               'EDO', 'BTG', 'DAT', 'KAN', 'QSH', 'YYW', 'GNT', 'SNT', 'BAT',
               'MNA', 'FUN', 'ZRX', 'TNB', 'SPK', 'AMP', 'TRX', 'RCN', 'RLC',
               'AID', 'SNG', 'REP', 'ELF', 'NEC', 'IOS', 'IQX', 'ALG', 'WPR',
               'ZIL', 'BNT', 'ABS', 'XRA', 'MAN', 'BBN', 'NIO', 'DGX', 'VET',
               'SWM', 'UTN', 'TKN', 'GOT', 'XTZ', 'CNN', 'BOX', 'MGO', 'RTE',
               'YGG', 'MLN', 'TRI', 'WTC', 'CSX', 'OMN', 'INT', 'DRN', 'PNK',
               'DGB', 'BSV', 'BAB', 'WLO', 'LOO', 'VLD', 'ENJ', 'ONL', 'RBT',
               'UST', 'EUT', 'GSD', 'UDC', 'TSD', 'PAX', 'UOS', 'RIF', 'PAS',
               'VSY', 'BTT', 'CLO', 'IMP', 'SCR', 'GNO', 'GEN', 'ATO', 'RRB',
               'WBT', 'XCH', 'EUS', 'LEO', 'AST', 'FOA', 'UFR', 'ZBT', 'OKB',
               'USK', 'DTX', 'FTT', 'CHZ']

dict_cryptos = { x : f"BITFINEX/{x}USD" for x in all_cryptos}

# %%
coinbase =['BTC', 'ETH', 'XRP', 'BCH', 'LTC', 'EOS', 'XLM', 'XTZ', 'ETC', 
           'DSH','BAT', 'ZEC', 'ZRX', 'REP','DAI','OXT']

# %%
coinbase_int = list(set(coinbase).intersection(set(all_cryptos)))
coinbase_int
# Out:
# ['XTZ',
#  'BAT',
#  'XRP',
#  'BTC',
#  'ZRX',
#  'ETC',
#  'EOS',
#  'LTC',
#  'DSH',
#  'ZEC',
#  'ETH',
#  'REP']

# %%
indexes=sorted([all_cryptos.index(x) for x in coinbase_int])

# %%
np.array(all_cryptos)[indexes]
# Out:
# array(['BTC', 'LTC', 'ETH', 'ETC', 'ZEC', 'DSH', 'XRP', 'EOS', 'BAT',
#        'ZRX', 'REP', 'XTZ'], dtype='<U3')

# %%
 import quandl# set up the Quandl connection
api_key = '3qg6_574job-qipYU3s_'
quandl.ApiConfig.api_key = api_key

quandl_code = "BITFINEX/BATUSD"# get the data from the API
bitcoin_data = quandl.get(quandl_code, start_date="2005-01-01", 
                          end_date="2020-03-18", returns="numpy")# set up the data in pandas
df = pd.DataFrame(data=bitcoin_data, columns=['Date', 'High', 'Low', 'Mid', 'Last', 'Bid', 'Ask', 'Volume'])# make the 'Date' column the index
df

df.set_index('Date')['Last'].iplot()

# %%
dict_cryptos
# Out:
# {'BTC': 'BITFINEX/BTCUSD',
#  'LTC': 'BITFINEX/LTCUSD',
#  'ETH': 'BITFINEX/ETHUSD',
#  'ETC': 'BITFINEX/ETCUSD',
#  'RRT': 'BITFINEX/RRTUSD',
#  'ZEC': 'BITFINEX/ZECUSD',
#  'XMR': 'BITFINEX/XMRUSD',
#  'DSH': 'BITFINEX/DSHUSD',
#  'XRP': 'BITFINEX/XRPUSD',
#  'IOT': 'BITFINEX/IOTUSD',
#  'GTX': 'BITFINEX/GTXUSD',
#  'EOS': 'BITFINEX/EOSUSD',
#  'SAN': 'BITFINEX/SANUSD',
#  'OMG': 'BITFINEX/OMGUSD',
#  'NEO': 'BITFINEX/NEOUSD',
#  'ETP': 'BITFINEX/ETPUSD',
#  'QTM': 'BITFINEX/QTMUSD',
#  'AVT': 'BITFINEX/AVTUSD',
#  'EDO': 'BITFINEX/EDOUSD',
#  'BTG': 'BITFINEX/BTGUSD',
#  'DAT': 'BITFINEX/DATUSD',
#  'KAN': 'BITFINEX/KANUSD',
#  'QSH': 'BITFINEX/QSHUSD',
#  'YYW': 'BITFINEX/YYWUSD',
#  'GNT': 'BITFINEX/GNTUSD',
#  'SNT': 'BITFINEX/SNTUSD',
#  'BAT': 'BITFINEX/BATUSD',
#  'MNA': 'BITFINEX/MNAUSD',
#  'FUN': 'BITFINEX/FUNUSD',
#  'ZRX': 'BITFINEX/ZRXUSD',
#  'TNB': 'BITFINEX/TNBUSD',
#  'SPK': 'BITFINEX/SPKUSD',
#  'AMP': 'BITFINEX/AMPUSD',
#  'TRX': 'BITFINEX/TRXUSD',
# ...

# %%
dfs=[]
for i  in all_cryptos:
    quandl_code = dict_cryptos[i] # get the data from the API
    bitcoin_data = quandl.get(quandl_code, start_date="2005-01-01", 
                              end_date="2020-01-02", returns="numpy")# set up the data in pandas
    df = (pd.DataFrame(data=bitcoin_data, columns=['Date', 'High', 'Low', 'Mid', 'Last', 'Bid', 'Ask', 'Volume']))
    df.set_index('Date',inplace=True)
    dfs.append(df)# make the 'Date' column the index

# %%
for j,i in enumerate(dfs):
    y = all_cryptos[j]
    i.columns = [f"{x}_{y}" for x in i.columns]

# %%
indexes
# Out:
# [0, 1, 2, 3, 5, 7, 8, 11, 26, 29, 38, 58]

# %%
np.array(all_cryptos)[[0, 1, 2, 3, 5, 7,8]]
# Out:
# array(['BTC', 'LTC', 'ETH', 'ETC', 'ZEC', 'DSH', 'XRP'], dtype='<U3')

# %%
dfsi = []
for i in [0, 1, 2]:
    dfsi.append(dfs[i])

# %%
all_df = pd.concat(dfsi,axis=1)

# %%
all_df.dropna(inplace=True)

# %%
all_df
# Out:
#                 High_BTC      Low_BTC   Mid_BTC     Last_BTC  Bid_BTC  \
# Date
# 2016-03-14    417.990000   411.700000   414.810   414.690000   414.78
# 2016-03-15    418.820000   412.780000   416.095   416.090000   416.08
# 2016-03-16    418.000000   413.960000   417.395   417.390000   417.39
# 2016-03-17    420.600000   416.670000   418.550   418.520000   418.52
# 2016-03-18    419.100000   403.010000   408.215   408.210000   408.21
# 2016-03-19    409.670000   404.000000   406.190   406.260000   406.14
# 2016-03-20    413.200000   406.060000   410.895   410.810000   410.81
# 2016-03-21    412.420000   406.000000   411.210   411.440000   411.00
# 2016-03-22    418.680000   409.880000   416.800   416.780000   416.78
# 2016-03-23    419.720000   415.830000   419.070   419.130000   419.01
# 2016-03-24    419.270000   414.000000   415.125   415.480000   415.12
# 2016-03-25    417.030000   413.030000   415.965   416.200000   415.84
# ...

# %%
# Out:
# 482.95

# %%
df = all_df[[x for x in all_df if x.startswith('Last')]]
df
# Out:
#                Last_BTC  Last_LTC    Last_ETH
# Date
# 2016-03-14   414.690000    3.2998   12.925000
# 2016-03-15   416.090000    3.2810   12.765000
# 2016-03-16   417.390000    3.3080   12.800000
# 2016-03-17   418.520000    3.2924   11.368000
# 2016-03-18   408.210000    3.1512   10.750000
# 2016-03-19   406.260000    3.1588   10.212000
# 2016-03-20   410.810000    3.1719   10.070000
# 2016-03-21   411.440000    3.1946   11.877000
# 2016-03-22   416.780000    3.2161   11.572000
# 2016-03-23   419.130000    3.2390   12.350000
# 2016-03-24   415.480000    3.2057   11.199000
# 2016-03-25   416.200000    3.2075   10.671000
# 2016-03-26   416.610000    3.2372   10.990000
# 2016-03-27   425.460000    3.2960   10.400000
# 2016-03-28   424.770000    3.2624   11.760000
# 2016-03-29   415.910000    3.2266   11.640000
# 2016-03-30   413.760000    3.2214   11.894000
# 2016-03-31   417.190000    3.2500   11.407000
# 2016-04-01   416.270000    3.2388   11.624000
# ...

# %%
all_df[[x for x in all_df.columns if 'Last' in x]].corr(method='spearman').iplot(kind='heatmap',colorscale='ylorrd')
# Out:
# <div>
#
#
#             <div id="3d2e64a5-d6c3-4c64-a4a6-7fef076c61e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3d2e64a5-d6c3-4c64-a4a6-7fef076c61e8")) {
#                     Plotly.newPlot(
#                         '3d2e64a5-d6c3-4c64-a4a6-7fef076c61e8',
# ...

# %%
df.columns
# Out:
# Index(['Last_BTC', 'Last_LTC', 'Last_ETH'], dtype='object')

# %%
l
# Out:
# [                   mean          min
#  Date
#  2016-03-14          NaN          NaN
#  2016-03-15          NaN          NaN
#  2016-03-16   415.390000   414.690000
#  2016-03-17   416.740000   416.090000
#  2016-03-18   417.955000   417.390000
#  2016-03-19   413.365000   408.210000
#  2016-03-20   407.235000   406.260000
#  2016-03-21   408.535000   406.260000
#  2016-03-22   411.125000   410.810000
#  2016-03-23   414.110000   411.440000
#  2016-03-24   417.955000   416.780000
#  2016-03-25   417.305000   415.480000
#  2016-03-26   415.840000   415.480000
#  2016-03-27   416.405000   416.200000
#  2016-03-28   421.035000   416.610000
#  2016-03-29   425.115000   424.770000
#  2016-03-30   420.340000   415.910000
#  2016-03-31   414.835000   413.760000
#  2016-04-01   415.475000   413.760000
#  2016-04-02   416.730000   416.270000
#  2016-04-03   418.285000   416.270000
#  2016-04-04   420.610000   420.300000
#  2016-04-05   420.760000   420.600000
# ...

# %%
def create_rollings(work_df, column, agg_func, windows, min_period=None):
    """
    work_df: un DataFrame
    column: str, columna a la cual se quiere applicar los rollings
    agg_func: str, funcion de agregacion de los rollings
    windows: iter, iterable con los numeros de ventanas para hacer los rollings
    min_periods: int, periodos minimos para agregar el rolling
    Return:
    DataFrame  con los las columnas hechas rolling
    """

    return pd.concat(map(lambda win: pd.DataFrame(work_df[column].rolling(window=win, min_periods=min_period).agg(agg_func).shift(1)).rename(columns=dict(zip(agg_func, [f'Rolling_{agg}_{column}_{win}' for agg in agg_func]))), windows), axis=1)


def create_shifts(work_df, column, shifts):
    """
    work_df: un DataFrame
    column: str, columna a la cual se quiere applicar los shift
    shifts: iterable con los numeros de shifts a aplicar

    """
    shift_df = pd.concat(map(lambda sh: work_df[column].shift(sh), shifts), axis=1)
    shift_df.columns = [f"{column}_shift_{sh}" for sh in shifts]
    return shift_df

# %%
create_rollings(df,'Last_BTC',['mean'],[2,7,15,30],None)
# Out:
#             Rolling_mean_Last_BTC_2  Rolling_mean_Last_BTC_7  \
# Date
# 2016-03-14                      NaN                      NaN
# 2016-03-15                      NaN                      NaN
# 2016-03-16               415.390000                      NaN
# 2016-03-17               416.740000                      NaN
# 2016-03-18               417.955000                      NaN
# 2016-03-19               413.365000                      NaN
# 2016-03-20               407.235000                      NaN
# 2016-03-21               408.535000               413.138571
# 2016-03-22               411.125000               412.674286
# 2016-03-23               414.110000               412.772857
# 2016-03-24               417.955000               413.021429
# 2016-03-25               417.305000               412.587143
# 2016-03-26               415.840000               413.728571
# 2016-03-27               416.405000               415.207143
# ...

# %%
create_shifts(df,'Last_BTC',range(1,5))
# Out:
#             Last_BTC_shift_1  Last_BTC_shift_2  Last_BTC_shift_3  \
# Date
# 2016-03-14               NaN               NaN               NaN
# 2016-03-15        414.690000               NaN               NaN
# 2016-03-16        416.090000        414.690000               NaN
# 2016-03-17        417.390000        416.090000        414.690000
# 2016-03-18        418.520000        417.390000        416.090000
# 2016-03-19        408.210000        418.520000        417.390000
# 2016-03-20        406.260000        408.210000        418.520000
# 2016-03-21        410.810000        406.260000        408.210000
# 2016-03-22        411.440000        410.810000        406.260000
# 2016-03-23        416.780000        411.440000        410.810000
# 2016-03-24        419.130000        416.780000        411.440000
# 2016-03-25        415.480000        419.130000        416.780000
# 2016-03-26        416.200000        415.480000        419.130000
# ...

# %%
16*3+30*3+3
# Out:
# 141

# %%
df = pd.concat([df]+
          
          [create_rollings(df,x,['mean','max','min','var'],[2,7,15,30],None) for x in df.columns]+
          [create_shifts(df,x,range(1,31)) for x in df.columns],
          
          axis=1)

# %%
df.shape
# Out:
# (1348, 141)

# %%
df.dropna(inplace=True)

# %%
df.corr(method='spearman').iplot(kind='heatmap',colorscale='ylorrd')
# Out:
# <div>
#
#
#             <div id="e5fda7bb-6624-4b46-ac61-307498cff47f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e5fda7bb-6624-4b46-ac61-307498cff47f")) {
#                     Plotly.newPlot(
#                         'e5fda7bb-6624-4b46-ac61-307498cff47f',
# ...

# %%
for i in range(31):
    print(df['Last_LTC'].autocorr(lag=i))
# Out:
# 1.0
# 0.9940801382192366
# 0.987816337696701
# 0.9811693836221168
# 0.9734935519297225
# 0.9667707571553635
# 0.958728438008737
# 0.9493778257412577
# 0.940848803184343
# 0.9314583053057917
# 0.923859355704286
# 0.9170108372463676
# 0.9096952592198895
# 0.9032015393771303
# 0.896590725426735
# 0.8895680759003323
# 0.8832405578421011
# 0.876985668177898
# 0.8711361589386982
# 0.8649483024194475
# 0.8584824677310499
# 0.8512788613208954
# 0.8440840031038542
# 0.8377601692668565
# 0.8312582471478244
# 0.8241198786021998
# 0.816053846997407
# 0.8087047299181304
# 0.8007350116559093
# 0.7937992994494277
# 0.7882342927889595

# %%
df.corr(method='spearman')['Last_LTC'].sort_values(ascending=False)
# Out:
# Last_LTC                    1.000000
# Last_LTC_shift_1            0.995579
# Rolling_mean_Last_LTC_2     0.994753
# Rolling_max_Last_LTC_2      0.994449
# Rolling_min_Last_LTC_2      0.993863
# Last_LTC_shift_2            0.991852
# Rolling_mean_Last_LTC_7     0.989634
# Rolling_max_Last_LTC_7      0.989443
# Last_LTC_shift_3            0.988364
# Rolling_min_Last_LTC_7      0.986916
# Last_LTC_shift_4            0.985405
# Last_LTC_shift_5            0.982675
# Rolling_max_Last_LTC_15     0.981993
# Rolling_mean_Last_LTC_15    0.981442
# Last_LTC_shift_6            0.979947
# Rolling_min_Last_LTC_15     0.978067
# Last_LTC_shift_7            0.977078
# Last_LTC_shift_8            0.974052
# Rolling_max_Last_LTC_30     0.973583
# Last_LTC_shift_9            0.971304
# Rolling_mean_Last_LTC_30    0.968988
# Last_LTC_shift_10           0.968746
# Last_LTC_shift_11           0.966068
# Rolling_min_Last_LTC_30     0.963207
# Last_LTC_shift_12           0.963183
# ...

# %%
df.corr(method='spearman')['Last_LTC'].sort_values().iloc[:10]
# Out:
# Rolling_var_Last_BTC_2     0.661660
# Rolling_var_Last_ETH_2     0.677020
# Rolling_var_Last_LTC_2     0.760133
# Rolling_var_Last_ETH_30    0.768314
# Rolling_var_Last_ETH_7     0.774059
# Rolling_var_Last_ETH_15    0.774752
# Rolling_var_Last_BTC_7     0.828165
# Last_BTC_shift_30          0.841034
# Last_BTC_shift_29          0.843295
# Rolling_var_Last_BTC_15    0.844825
# Name: Last_LTC, dtype: float64

# %%
df[['Profit_ETC',
       'Profit_ZEC', 'Rolling_mean_Profit_ETC_2', 'Rolling_mean_Profit_ETC_7',
    'Rolling_mean_Profit_ZEC_2', 'Rolling_mean_Profit_ZEC_7',
    'Profit_ETC_shift_1', 'Profit_ETC_shift_2', 'Profit_ETC_shift_3','Profit_ETC_shift_30',
    'Profit_ZEC_shift_1', 'Profit_ZEC_shift_2', 'Profit_ZEC_shift_3','Profit_ZEC_shift_30'
   ]].corr(method='spearman').iplot(kind='heatmap',colorscale='ylorrd')
# Out:
# <div>
#
#
#             <div id="6f74302a-0bf4-4d6a-a9b0-2dad54b7ef2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6f74302a-0bf4-4d6a-a9b0-2dad54b7ef2d")) {
#                     Plotly.newPlot(
#                         '6f74302a-0bf4-4d6a-a9b0-2dad54b7ef2d',
# ...

# %%
df[['Profit_ETC',
       'Profit_ZEC', 'Rolling_mean_Profit_ETC_2', 'Rolling_mean_Profit_ETC_7',
    'Rolling_mean_Profit_ZEC_2', 'Rolling_mean_Profit_ZEC_7',
    'Profit_ETC_shift_1', 'Profit_ETC_shift_2', 'Profit_ETC_shift_3','Profit_ETC_shift_30',
    'Profit_ZEC_shift_1', 'Profit_ZEC_shift_2', 'Profit_ZEC_shift_3','Profit_ZEC_shift_30'
   ]].corr().iplot(kind='heatmap',colorscale='ylorrd')
# Out:
# <div>
#
#
#             <div id="fa49ba6d-a742-472f-99f2-3320b1a79573" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fa49ba6d-a742-472f-99f2-3320b1a79573")) {
#                     Plotly.newPlot(
#                         'fa49ba6d-a742-472f-99f2-3320b1a79573',
# ...

# %%
df['resta_diario'] = df['High']-df['Low']
df['rate_diario'] = ( df['High']-df['Low'])/ df['High']
df['First'] = df['Last'].shift(1)
df
# Out:
#                High      Low     Last      Bid      Ask        Volume  \
# Date
# 2014-04-15   515.00   453.16   499.01   500.01   505.04  28535.844106
# 2014-04-16   548.00   494.02   534.00   535.01   536.00  31159.941300
# 2014-04-17   537.24   481.63   506.52   504.70   505.38  21126.375080
# 2014-04-18   508.43   470.00   487.00   484.14   487.00  11879.484756
# 2014-04-19   507.43   472.81   504.74   504.74   505.00  10262.195861
# 2014-04-20   516.53   493.00   496.20   496.20   499.30   6034.641139
# 2014-04-21   515.00   490.00   497.00   496.31   496.99   8429.045723
# 2014-04-22   504.90   486.44   489.50   488.27   489.50   7651.358032
# 2014-04-23   495.20   484.61   491.31   491.80   491.89   6490.422327
# 2014-04-24   499.00   480.00   498.32   496.16   498.32   6875.473428
# 2014-04-25   505.00   438.05   463.54   462.50   463.50  32311.719807
# 2014-04-26   470.96   451.07   459.00   459.00   460.00  10885.104866
# ...

# %%
df['delta_day']=df['Last']-df['First']
df['delta_rate_day']=(df['Last']-df['First'])/df['Last']
df
# Out:
#                High      Low     Last      Bid      Ask        Volume  \
# Date
# 2014-04-15   515.00   453.16   499.01   500.01   505.04  28535.844106
# 2014-04-16   548.00   494.02   534.00   535.01   536.00  31159.941300
# 2014-04-17   537.24   481.63   506.52   504.70   505.38  21126.375080
# 2014-04-18   508.43   470.00   487.00   484.14   487.00  11879.484756
# 2014-04-19   507.43   472.81   504.74   504.74   505.00  10262.195861
# 2014-04-20   516.53   493.00   496.20   496.20   499.30   6034.641139
# 2014-04-21   515.00   490.00   497.00   496.31   496.99   8429.045723
# 2014-04-22   504.90   486.44   489.50   488.27   489.50   7651.358032
# 2014-04-23   495.20   484.61   491.31   491.80   491.89   6490.422327
# 2014-04-24   499.00   480.00   498.32   496.16   498.32   6875.473428
# 2014-04-25   505.00   438.05   463.54   462.50   463.50  32311.719807
# 2014-04-26   470.96   451.07   459.00   459.00   460.00  10885.104866
# ...

# %%
df['RollingMean_30'] = df['Last'].rolling(window=30).mean().shift(1)# label when the last price is less than L30D average
df['RollingMean_15'] = df['Last'].rolling(window=15).mean().shift(1)# label when the last price is less than L30D average
df['RollingMean_7'] = df['Last'].rolling(window=7).mean().shift(1)# label when the last price is less than L30D average

df['RollingStd_30'] = df['Last'].rolling(window=30).std().shift(1)# label when the last price is less than L30D average
df['RollingStd_15'] = df['Last'].rolling(window=15).std().shift(1)# label when the last price is less than L30D average
df['RollingStd_7'] = df['Last'].rolling(window=7).std().shift(1)# label when the last price is less than L30D average

df['RollingVar_30'] = df['Last'].rolling(window=30).var().shift(1)# label when the last price is less than L30D average
df['RollingVar_15'] = df['Last'].rolling(window=15).var().shift(1)# label when the last price is less than L30D average
df['RollingVar_7'] = df['Last'].rolling(window=7).var().shift(1)# label when the last price is less than L30D average

# %%
df['RollingMean_rate_30'] = df['delta_rate_day'].rolling(window=30).mean().shift(1)# label when the last price is less than L30D average
df['RollingMean_rate_15'] = df['delta_rate_day'].rolling(window=15).mean().shift(1)# label when the last price is less than L30D average
df['RollingMean_rate_7'] = df['delta_rate_day'].rolling(window=7).mean().shift(1)# label when the last price is less than L30D average

df['RollingStd_rate_30'] = df['delta_rate_day'].rolling(window=30).std().shift(1)# label when the last price is less than L30D average
df['RollingStd_rate_15'] = df['delta_rate_day'].rolling(window=15).std().shift(1)# label when the last price is less than L30D average
df['RollingStd_rate_7'] = df['delta_rate_day'].rolling(window=7).std().shift(1)# label when the last price is less than L30D average

# %%
# %%timeit
df['RollingVar_rate_30'] = df['delta_rate_day'].rolling(window=30).var().shift(1)# label when the last price is less than L30D average
df['RollingVar_rate_15'] = df['delta_rate_day'].rolling(window=15).var().shift(1)# label when the last price is less than L30D average
df['RollingVar_rate_7'] = df['delta_rate_day'].rolling(window=7).var().shift(1)# label when the last price is less than L30D average
# Out:
# 1.51 ms ± 3.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# def create_rollings(work_df,column,agg_func,windows):
#     return pd.DataFrame(np.stack(list(map(lambda f: list(map(lambda win: work_df[column].rolling(window=win).agg(f).shift(1), windows)),agg_func)),axis=1),columns=[f'Rolling_{agg_func}_{column}_{win}' for win in windows])
import pandas as pd
import numpy as np

# %%
holis = pd.DataFrame(pd.np.random.uniform(size=(100,3)),columns=['a','b','c'])

# %%
holis
# Out:
#            a         b         c
# 0   0.178794  0.839944  0.927806
# 1   0.016331  0.637524  0.791381
# 2   0.898141  0.794493  0.910618
# 3   0.920280  0.349096  0.120776
# 4   0.878931  0.770832  0.155911
# ..       ...       ...       ...
# 95  0.421057  0.792878  0.531194
# 96  0.658757  0.244571  0.280506
# 97  0.790184  0.226806  0.326404
# 98  0.149854  0.711961  0.937544
# 99  0.882276  0.125762  0.064957
#
# [100 rows x 3 columns]

# %%
import sys
# !{sys.executable} -m pip install Arty
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement Arty (from versions: none)
# ERROR: No matching distribution found for Arty
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# df.reset_index(inplace=True)
df.tail()
# Out:
#            Date     High      Low     Last      Bid      Ask       Volume  \
# 2029 2019-12-30  7524.46  7274.43  7385.54  7379.25  7386.17  2583.719082
# 2030 2019-12-31  7384.90  7199.00  7222.74  7215.00  7221.10  3723.031482
# 2031 2020-01-01  7302.35  7112.55  7168.36  7164.40  7170.96  2638.573176
# 2032 2020-01-02  7237.35  7150.00  7178.68  7172.68  7178.42  1119.109693
# 2033 2020-01-03  7184.94  6900.00  6945.70  6944.67  6949.09  4003.778298
#
#          VWAP  resta_diario  rate_diario    First  delta_day  delta_rate_day  \
# 2029  7399.88        250.03     0.033229  7297.43      88.11        0.011930
# 2030  7281.12        185.90     0.025173  7385.54    -162.80       -0.022540
# 2031  7194.68        189.80     0.025992  7222.74     -54.38       -0.007586
# 2032  7195.25         87.35     0.012069  7168.36      10.32        0.001438
# 2033  7029.56        284.94     0.039658  7178.68    -232.98       -0.033543
#
# ...

# %%
create_rollings(work_df=df,column='Last',agg_func='var',windows=[30,15,7])
# Out:
#       Rolling_var_Last_30  Rolling_var_Last_15  Rolling_var_Last_7
# 0                     NaN                  NaN                 NaN
# 1                     NaN                  NaN                 NaN
# 2                     NaN                  NaN                 NaN
# 3                     NaN                  NaN                 NaN
# 4                     NaN                  NaN                 NaN
# 5                     NaN                  NaN                 NaN
# 6                     NaN                  NaN                 NaN
# 7                     NaN                  NaN         1286.498195
# 8                     NaN                  NaN         1286.640957
# 9                     NaN                  NaN         1522.720014
# 10                    NaN                  NaN         1240.947729
# 11                    NaN                  NaN         1095.543995
# 12                    NaN                  NaN          707.000148
# ...

# %%
create_shifts(work_df=holis,column='b',shifts=[1,2,3,4,56])
# Out:
#     b_shift_1  b_shift_2  b_shift_3  b_shift_4  b_shift_56
# 0         NaN        NaN        NaN        NaN         NaN
# 1    0.839944        NaN        NaN        NaN         NaN
# 2    0.637524   0.839944        NaN        NaN         NaN
# 3    0.794493   0.637524   0.839944        NaN         NaN
# 4    0.349096   0.794493   0.637524   0.839944         NaN
# ..        ...        ...        ...        ...         ...
# 95   0.293428   0.521699   0.948694   0.811540    0.809955
# 96   0.792878   0.293428   0.521699   0.948694    0.440516
# 97   0.244571   0.792878   0.293428   0.521699    0.192700
# 98   0.226806   0.244571   0.792878   0.293428    0.323766
# 99   0.711961   0.226806   0.244571   0.792878    0.103055
#
# [100 rows x 5 columns]

# %%
df[[x for x in df if 'High' in x]]
# Out:
#           High
# 0       451.48
# 1       451.43
# 2       450.00
# 3       500.00
# 4       499.10
# 5       528.87
# 6       547.10
# 7       532.64
# 8       586.34
# 9       593.48
# 10      595.00
# 11      582.26
# 12      582.10
# 13      624.36
# 14      629.40
# 15      683.26
# 16      677.77
# 17      680.99
# 18      673.87
# 19      669.63
# 20      664.97
# 21      656.84
# 22      661.11
# 23      659.00
# 24      657.41
# 25      652.39
# 26      630.36
# 27      611.99
# 28      593.53
# 29      576.64
# 30      610.00
# 31      608.88
# 32      616.00
# 33      609.98
# 34      598.68
# 35      594.97
# 36      605.05
# 37      601.00
# 38      588.67
# 39      582.82
# 40      574.93
# 41      590.00
# 42      604.21
# 43      601.79
# 44      647.09
# 45      658.88
# 46      658.75
# 47      652.79
# 48      650.48
# 49      632.97
# 50      639.00
# 51      636.00
# 52      626.62
# 53      626.88
# 54      624.35
# 55      635.00
# 56      642.57
# ...

# %%
for i in range(1,31):
    exec(f"df['Last_{i}']=df['Last'].shift({i})")
for i in range(1,31):
    exec(f"df['delta_day_{i}']=df['delta_day'].shift({i})")
for i in range(1,31):
    exec(f"df['delta_rate_day_{i}']=df['delta_rate_day'].shift({i})")

# %%
df.reset_index(inplace=True)

# %%
df['Rachas_up_30'] = df['Up'].rolling(window=30).sum().shift(1)# label when the last price is less than L30D average
df['Rachas_up_15'] = df['Up'].rolling(window=15).sum().shift(1)# label when the last price is less than L30D average
df['Rachas_up_7'] = df['Up'].rolling(window=7).sum().shift(1)# label when the last price is less than L30D average

# %%
df.Up[:30].sum()
# Out:
# 18

# %%
df['Up']
# Out:
# Date
# 2014-05-17    1
# 2014-05-18    0
# 2014-05-19    1
# 2014-05-20    1
# 2014-05-21    1
# 2014-05-22    1
# 2014-05-23    1
# 2014-05-24    0
# 2014-05-25    1
# 2014-05-26    1
# 2014-05-27    0
# 2014-05-28    0
# 2014-05-29    0
# 2014-05-30    1
# 2014-05-31    1
# 2014-06-01    1
# 2014-06-02    1
# 2014-06-03    0
# 2014-06-04    0
# 2014-06-05    1
# 2014-06-06    0
# 2014-06-07    1
# 2014-06-08    1
# 2014-06-09    0
# 2014-06-10    1
# 2014-06-11    0
# 2014-06-12    0
# 2014-06-13    1
# 2014-06-14    0
# 2014-06-15    1
# 2014-06-16    1
# 2014-06-17    1
# 2014-06-18    1
# 2014-06-19    0
# 2014-06-20    0
# 2014-06-21    0
# 2014-06-22    1
# 2014-06-23    0
# 2014-06-24    0
# 2014-06-25    0
# 2014-06-26    1
# 2014-06-27    1
# 2014-06-28    1
# 2014-06-29    0
# 2014-06-30    1
# 2014-07-01    1
# 2014-07-02    1
# 2014-07-03    0
# 2014-07-04    0
# 2014-07-05    0
# 2014-07-06    1
# 2014-07-07    0
# 2014-07-08    1
# 2014-07-09    1
# 2014-07-10    0
# ...

# %%
df = pd.concat([df,pd.get_dummies(df.Date.dt.weekday).rename(columns={0:'Lunes',1:'Martes',2:'Miercoles',3:'Jueves',4:'Viernes',5:'Sabado',6:'Domingo'})],axis=1)

# %%
df.dropna(inplace=True)

# %%
df.tail()
# Out:
#            Date     High      Low     Last      Bid      Ask       Volume  \
# 2060 2019-12-30  7524.46  7274.43  7385.54  7379.25  7386.17  2583.719082
# 2061 2019-12-31  7384.90  7199.00  7222.74  7215.00  7221.10  3723.031482
# 2062 2020-01-01  7302.35  7112.55  7168.36  7164.40  7170.96  2638.573176
# 2063 2020-01-02  7237.35  7150.00  7178.68  7172.68  7178.42  1119.109693
# 2064 2020-01-03  7184.94  6900.00  6945.70  6944.67  6949.09  4003.778298
#
#          VWAP  resta_diario  rate_diario    First  delta_day  delta_rate_day  \
# 2060  7399.88        250.03     0.033229  7297.43      88.11        0.011930
# 2061  7281.12        185.90     0.025173  7385.54    -162.80       -0.022540
# 2062  7194.68        189.80     0.025992  7222.74     -54.38       -0.007586
# 2063  7195.25         87.35     0.012069  7168.36      10.32        0.001438
# 2064  7029.56        284.94     0.039658  7178.68    -232.98       -0.033543
#
# ...

# %%
df
# Out:
#            Date     High      Low     Last      Bid      Ask        Volume  \
# 31   2014-05-17   451.48   445.01   450.67   449.03   450.68   2389.082378
# 32   2014-05-18   451.43   444.52   446.28   446.25   446.28   2505.628357
# 33   2014-05-19   450.00   441.44   447.08   447.08   447.72   4649.905517
# 34   2014-05-20   500.00   446.24   486.98   484.62   486.70  27451.566419
# 35   2014-05-21   499.10   484.80   494.38   494.37   494.38   7763.720323
# 36   2014-05-22   528.87   492.65   525.00   523.91   525.00  16566.994930
# 37   2014-05-23   547.10   519.97   529.11   529.11   529.47  19281.292893
# 38   2014-05-24   532.64   515.40   525.62   525.62   526.00   6528.662024
# 39   2014-05-25   586.34   524.50   569.82   569.80   570.93  19696.487565
# 40   2014-05-26   593.48   565.58   581.93   580.85   581.93  11987.537520
# 41   2014-05-27   595.00   550.22   577.00   577.00   577.55  19376.392286
# ...

# %%
df.set_index('Date',inplace=True)

# %%
df.delta_rate_day
# Out:
# Date
# 2014-05-17    0.002130
# 2014-05-18   -0.009837
# 2014-05-19    0.001789
# 2014-05-20    0.081934
# 2014-05-21    0.014968
# 2014-05-22    0.058324
# 2014-05-23    0.007768
# 2014-05-24   -0.006640
# 2014-05-25    0.077568
# 2014-05-26    0.020810
# 2014-05-27   -0.008544
# 2014-05-28   -0.004352
# 2014-05-29   -0.005267
# 2014-05-30    0.082018
# 2014-05-31    0.004780
# 2014-06-01    0.024149
# 2014-06-02    0.047037
# 2014-06-03   -0.004120
# 2014-06-04   -0.036997
# 2014-06-05    0.028118
# 2014-06-06   -0.016330
# 2014-06-07    0.003201
# 2014-06-08    0.000137
# 2014-06-09   -0.015789
# 2014-06-10    0.000139
#                 ...
# 2019-12-10   -0.025031
# 2019-12-11   -0.017246
# 2019-12-12   -0.000988
# 2019-12-13   -0.002856
# 2019-12-14    0.009305
# 2019-12-15   -0.027895
# 2019-12-16    0.007878
# 2019-12-17   -0.033856
# 2019-12-18   -0.040800
# 2019-12-19    0.093031
# 2019-12-20   -0.019719
# 2019-12-21    0.006191
# 2019-12-22   -0.006535
# ...

# %%
df['delta_rate_day'].iplot(kind='line')
# Out:
# <div>
#
#
#             <div id="3eab2fa7-b8c2-4b09-98e8-9d00298c1525" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3eab2fa7-b8c2-4b09-98e8-9d00298c1525")) {
#                     Plotly.newPlot(
#                         '3eab2fa7-b8c2-4b09-98e8-9d00298c1525',
# ...

# %%
df['Up'] = df.delta_rate_day.map(lambda x: 1 if x>0 else 0)

# %%
df
# Out:
#                High      Low     Last      Bid      Ask        Volume  \
# Date
# 2014-05-17   451.48   445.01   450.67   449.03   450.68   2389.082378
# 2014-05-18   451.43   444.52   446.28   446.25   446.28   2505.628357
# 2014-05-19   450.00   441.44   447.08   447.08   447.72   4649.905517
# 2014-05-20   500.00   446.24   486.98   484.62   486.70  27451.566419
# 2014-05-21   499.10   484.80   494.38   494.37   494.38   7763.720323
# 2014-05-22   528.87   492.65   525.00   523.91   525.00  16566.994930
# 2014-05-23   547.10   519.97   529.11   529.11   529.47  19281.292893
# 2014-05-24   532.64   515.40   525.62   525.62   526.00   6528.662024
# 2014-05-25   586.34   524.50   569.82   569.80   570.93  19696.487565
# 2014-05-26   593.48   565.58   581.93   580.85   581.93  11987.537520
# 2014-05-27   595.00   550.22   577.00   577.00   577.55  19376.392286
# 2014-05-28   582.26   563.45   574.50   572.59   574.50   8672.887285
# ...

# %%
feat_cont = ['delta_rate_day_1', 'delta_rate_day_2', 'delta_rate_day_3', 'delta_rate_day_4', 'delta_rate_day_5',
 'delta_rate_day_6', 'delta_rate_day_7', 'delta_rate_day_8', 'delta_rate_day_9', 'delta_rate_day_10',
 'delta_rate_day_11', 'delta_rate_day_12', 'delta_rate_day_13', 'delta_rate_day_14', 'delta_rate_day_15',
 'delta_rate_day_16', 'delta_rate_day_17', 'delta_rate_day_18', 'delta_rate_day_19', 'delta_rate_day_20',
 'delta_rate_day_21', 'delta_rate_day_22', 'delta_rate_day_23', 'delta_rate_day_24', 'delta_rate_day_25',
 'delta_rate_day_26', 'delta_rate_day_27', 'delta_rate_day_28', 'delta_rate_day_29', 'delta_rate_day_30',
 'Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo']
['RollingMean_30',
 'RollingMean_15',
 'RollingMean_7',
 'RollingStd_30',
 'RollingStd_15',
 'RollingStd_7',
 'RollingVar_30',
 'RollingVar_15',
 'RollingVar_7']
tgt = ['Up','delta_rate_day','Last']

# %%
[x for x in df if 'Rolling' in x]
# Out:
# ['RollingMean_30',
#  'RollingMean_15',
#  'RollingMean_7',
#  'RollingStd_30',
#  'RollingStd_15',
#  'RollingStd_7',
#  'RollingVar_30',
#  'RollingVar_15',
#  'RollingVar_7']

# %%
df[['Up','delta_rate_day','Lunes', 'Martes', 
    'Miercoles', 'Jueves', 'Viernes', 'Sabado', 
    'Domingo']+[x for x in df if x.startswith('Rachas')]].corr(method='spearman').iplot(kind='heatmap',colorscale='ylorrd')
# Out:
# <div>
#
#
#             <div id="036eb74e-b9a4-4758-8946-7cfd4de10449" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("036eb74e-b9a4-4758-8946-7cfd4de10449")) {
#                     Plotly.newPlot(
#                         '036eb74e-b9a4-4758-8946-7cfd4de10449',
# ...

# %%
from xgboost.sklearn import XGBClassifier,XGBRegressor
from sklearn.preprocessing import MinMaxScaler 
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,roc_curve, auc
import matplotlib.pyplot as plt

# %%
mm = MinMaxScaler()
mm.fit(df[feat_cont])
X = pd.DataFrame(mm.transform(df[feat_cont]),columns=feat_cont).tail(700).reset_index(drop=True)
y = df['Up'].tail(700).reset_index(drop=True)

# %%
from sklearn.utils import shuffle

X_train = shuffle(X.loc[:500])
X_test = shuffle(X.loc[500:])

# %%
y_train = y.loc[X_train.index]
y_test = y.loc[X_test.index]

# %%
train_X = X_train.values
train_y = y_train.values
test_X = X_test.values
test_y = y_test.values
(train_X.shape,
train_y.shape,
test_X.shape,
test_y.shape)
# Out:
# ((501, 37), (501,), (200, 37), (200,))

# %%
#reshape para el modelo 
train_X = train_X.reshape(train_X.shape[0],train_X.shape[1],1)
test_X = test_X.reshape(test_X.shape[0],test_X.shape[1],1)
(
train_X.shape,
train_y.shape,
test_X.shape,
test_y.shape)
# Out:
# ((501, 37, 1), (501,), (200, 37, 1), (200,))

# %%
import sys

# %%
# !{sys.executable} -m pip install keras==2.2.5
# !{sys.executable} -m pip install tensorflow==1.14.0
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/f8/ba/2d058dcf1b85b9c212cc58264c98a4a7dd92c989b798823cc5690d062bb2/Keras-2.2.5-py2.py3-none-any.whl
# ...
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
#   Using cached https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl
# ...
#   Found existing installation: tensorboard 2.0.2
# ...

# %%
#Modelo 
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
import  time

# %%
# Definimos modelo de LSTM
model = Sequential()
model.add(LSTM(input_shape = (37,1), output_dim= 37, return_sequences = True))
model.add(Activation("sigmoid"))
# model.add(Dropout(0.1))
model.add(LSTM(256))
model.add(Activation("sigmoid"))
# model.add(Dropout(0.1))
model.add(Dense(100))

model.add(Activation("sigmoid"))
model.add(Dense(256))
model.add(Activation("sigmoid"))
# model.add(Dropout(0.1))
model.add(Dense(1))
model.add(Activation("sigmoid"))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

start = time.time()
model.fit(train_X,train_y,batch_size=50,nb_epoch=700,validation_split=0.1)
print("> Compilation Time : ", time.time() - start)
# Out:
# /home/derek/venv/fant4stic/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning:
#
# Update your `LSTM` call to the Keras 2 API: `LSTM(input_shape=(37, 1), return_sequences=True, units=37)`
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_28 (LSTM)               (None, 37, 37)            5772
# _________________________________________________________________
# activation_32 (Activation)   (None, 37, 37)            0
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 256)               301056
# _________________________________________________________________
# activation_33 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               25700
# ...

# %%
 model.predict(train_X)
# Out:
# array([[0.54879326],
#        [0.5487931 ],
#        [0.54879314],
#        [0.5487931 ],
#        [0.54879326],
#        [0.5487931 ],
#        [0.54879314],
#        [0.5487933 ],
#        [0.5487935 ],
#        [0.5487931 ],
#        [0.5487931 ],
#        [0.54879326],
#        [0.5487931 ],
#        [0.54879344],
#        [0.5487931 ],
#        [0.5487931 ],
#        [0.54879326],
#        [0.5487931 ],
#        [0.5487931 ],
#        [0.5487931 ],
#        [0.54879314],
#        [0.54879314],
#        [0.5487933 ],
#        [0.54879344],
#        [0.54879344],
#        [0.54879314],
#        [0.5487931 ],
#        [0.54879344],
#        [0.5487935 ],
#        [0.54879314],
#        [0.5487933 ],
#        [0.54879326],
#        [0.5487932 ],
#        [0.5487932 ],
#        [0.5487931 ],
#        [0.5487931 ],
#        [0.54879326],
#        [0.54879326],
#        [0.5487931 ],
#        [0.5487931 ],
#        [0.5487933 ],
#        [0.54879314],
#        [0.5487932 ],
# ...

# %%
# Doing a prediction on all the train data at once
preds = model.predict_proba(train_X)


actuals =train_y.reshape(-1,1)
# actuals = train_y

print(roc_auc_score(actuals,preds))
# Out:
# 0.5517222062165882

# %%
# Doing a prediction on all the test data at once
preds = model.predict_proba(test_X)


actuals =test_y.reshape(-1,1)
# actuals = test_y

print(roc_auc_score(actuals,preds))
# Out:
# 0.5094339622641509

# %% [markdown]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.7)

# %%
xgb = XGBClassifier(n_jobs=7)

# %%
xgb.fit(X=X_train,y=y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=7,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
print('Train: ',roc_auc_score( y_true=y_train,    y_score=xgb.predict_proba(X_train)[:,1]))
print('Test: ',roc_auc_score( y_true=y_test,    y_score=xgb.predict_proba(X_test)[:,1]))
# Out:
# Train:  0.9985915042094817
# Test:  0.509233239662786

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
# Plot of a ROC curve for a specific class

plt.figure()
lw = 2
plt.plot(fpr[2], tpr[2], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-d8d874287039> in <module>
#       3 tpr = dict()
#       4 roc_auc = dict()
# ----> 5 for i in range(n_classes):
#       6     fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
#       7     roc_auc[i] = auc(fpr[i], tpr[i])
#
# NameError: name 'n_classes' is not defined

# %%
import sys
# !{sys.executable} -m pip install newsapi-python
# Out:
# ...
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='f4f85aabb9434483b2d05201e573f3eb')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='trump',
                                          
                                          
                                          language='en',
                                          country='us')

# /v2/everything
all_articles = newsapi.get_everything(q='trump',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2020-01-01',
                                      to='2020-01-06',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)

# /v2/sources
sources = newsapi.get_sources()
# Need to talk to someone? E

# %%
all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 59,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Brian Heater',
#    'title': 'What to Expect from CES 2020',
#    'description': 'It’s the second most wonderful time of the year. As the rest of the world returns to work, nursing a week-long New Year’s hangover, bright-eyed and bushy-tailed tech journalists will descend upon Sin City to discover the biggest news the tech world has to off…',
#    'url': 'http://techcrunch.com/2020/01/03/what-to-expect-from-ces-2020/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/01/ces-2020-splash.png?w=753',
#    'publishedAt': '2020-01-03T23:21:05Z',
#    'content': 'Its the second most wonderful time of the year. As the rest of the world returns to work, nursing a week-long New Year’s hangover, bright-eyed and bushy-tailed tech journalists will descend upon Sin City to discover the biggest news the tech world has to offe… [+4926 chars]'},
# ...

# %%
top_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 2,
#  'articles': [{'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'Allan Smith',
#    'title': 'Pelosi announces war powers resolution as tensions with Iran escalate - NBC News',
#    'description': 'Nancy Pelosi announced the House will take up a war powers resolution in response to President Donald Trump ordering the killing of an Iranian general.',
#    'url': 'https://www.nbcnews.com/politics/national-security/pelosi-announces-war-powers-resolution-tensions-iran-escalate-n1111041',
#    'urlToImage': 'https://media2.s-nbcnews.com/j/newscms/2020_02/3172346/200106-nancy-pelosi-mc-1122_08e28337c9b0b9e5e3eacfe26d97dbec.nbcnews-fp-1200-630.JPG',
#    'publishedAt': '2020-01-06T13:46:00Z',
# ...

# %%
sources
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'abc-news',
#    'name': 'ABC News',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'url': 'https://abcnews.go.com',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'abc-news-au',
#    'name': 'ABC News (AU)',
#    'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#    'url': 'http://www.abc.net.au/news',
#    'category': 'general',
#    'language': 'en',
#    'country': 'au'},
#   {'id': 'aftenposten',
#    'name': 'Aftenposten',
#    'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#    'url': 'https://www.aftenposten.no',
#    'category': 'general',
#    'language': 'no',
#    'country': 'no'},
# ...

# %%
from __future__ import print_function

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D
from keras.datasets import imdb

# Embedding
max_features = 20000
maxlen = 100
embedding_size = 128

# Convolution
kernel_size = 5
filters = 64
pool_size = 4

# LSTM
lstm_output_size = 70

# Training
batch_size = 30
epochs = 2

'''
Note:
batch_size is highly sensitive.
Only 2 epochs are needed as the dataset is very small.
'''

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)

print('Build model...')

model = Sequential()
model.add(Embedding(max_features, embedding_size, input_length=maxlen))
model.add(Dropout(0.25))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
model.add(MaxPooling1D(pool_size=pool_size))
model.add(LSTM(lstm_output_size))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Using TensorFlow backend.
# /home/derek/venv/fant4stic/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/derek/venv/fant4stic/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/derek/venv/fant4stic/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
df['P(X>0)']

# %%
df['Buy'] = df['Last'] < df['RollingMean']# create a strategic trading DataFrame

# %%
trading_info = df.loc[:,['Last', 'RollingMean', 'Buy']]

# %%
trading_info.tail(10) # lets look at last 10 days                Last   RollingMean    BuyDate2018-01-08  16173.98  15693.421333  False2018-01-09  15000.00  15704.147667   True2018-01-10  14397.30  15716.680333   True2018-01-11  14900.00  15706.590333   True2018-01-12  13220.00  15655.209333   True2018-01-13  13829.29  15539.209333   True2018-01-14  14189.66  15458.548000   True2018-01-15  13648.00  15384.760000   True2018-01-16  13581.66  15258.109000   True2018-01-17  11378.66  15070.668667   True
# Out:
#   File "<ipython-input-1-1a64c012c7ca>", line 10
#     trading_info = df.loc[:,['Last', 'RollingMean', 'Buy']]>>> trading_info.tail(10) # lets look at last 10 days                Last   RollingMean    BuyDate2018-01-08  16173.98  15693.421333  False2018-01-09  15000.00  15704.147667   True2018-01-10  14397.30  15716.680333   True2018-01-11  14900.00  15706.590333   True2018-01-12  13220.00  15655.209333   True2018-01-13  13829.29  15539.209333   True2018-01-14  14189.66  15458.548000   True2018-01-15  13648.00  15384.760000   True2018-01-16  13581.66  15258.109000   True2018-01-17  11378.66  15070.668667   True
#                                                              ^
# SyntaxError: invalid syntax
